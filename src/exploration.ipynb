# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

BASE_DIR = os.getcwd()

DATA_PATH = os.path.join(BASE_DIR, "..", "data", "fashion_products.csv")

data = pd.read_csv(DATA_PATH)

data.head()
# Out:
#    User ID  Product ID Product Name   Brand         Category  Price    Rating  \
# 0       19           1        Dress  Adidas    Men's Fashion     40  1.043159
# 1       97           2        Shoes     H&M  Women's Fashion     82  4.026416
# 2       25           3        Dress  Adidas  Women's Fashion     44  3.337938
# 3       57           4        Shoes    Zara    Men's Fashion     23  1.049523
# 4       79           5      T-shirt  Adidas    Men's Fashion     79  4.302773
#
#     Color Size
# 0   Black   XL
# 1   Black    L
# 2  Yellow   XL
# 3   White    S
# 4   Black    M

# %% [markdown]
# # Data Exploration:

# %%
data.head(2)
# Out:
#    User ID  Product ID Product Name   Brand         Category  Price    Rating  \
# 0       19           1        Dress  Adidas    Men's Fashion     40  1.043159
# 1       97           2        Shoes     H&M  Women's Fashion     82  4.026416
#
#    Color Size
# 0  Black   XL
# 1  Black    L

# %%
data[data['Price'] < 40].shape[0]
# Out:
# 322

# %%
data['Price'].sum()
# Out:
# np.int64(55785)

# %%
data.head(2)
# Out:
#    User ID  Product ID Product Name   Brand         Category  Price    Rating  \
# 0       19           1        Dress  Adidas    Men's Fashion     40  1.043159
# 1       97           2        Shoes     H&M  Women's Fashion     82  4.026416
#
#    Color Size
# 0  Black   XL
# 1  Black    L

# %%
data[data['Size'] == 'L']
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 1         97           2        Shoes     H&M  Women's Fashion     82
# 5         98           6        Dress  Adidas    Men's Fashion     47
# 13        50          14        Dress    Zara  Women's Fashion     34
# 19        56          20        Dress   Gucci    Men's Fashion     53
# 21        56          22        Jeans   Gucci  Women's Fashion     89
# ..       ...         ...          ...     ...              ...    ...
# 990       60         991        Shoes    Nike    Kids' Fashion     25
# 993       59         994      Sweater     H&M    Men's Fashion     89
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 1    4.026416   Black    L
# 5    1.379566  Yellow    L
# 13   2.921004   White    L
# 19   3.785245   Green    L
# 21   4.568632   Green    L
# ..        ...     ...  ...
# 990  4.972677     Red    L
# 993  4.440833   Green    L
# 996  1.544464   Green    L
# 997  3.961913   White    L
# 999  3.093553   White    L
#
# [251 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User ID       1000 non-null   int64
#  1   Product ID    1000 non-null   int64
#  2   Product Name  1000 non-null   object
#  3   Brand         1000 non-null   object
#  4   Category      1000 non-null   object
#  5   Price         1000 non-null   int64
#  6   Rating        1000 non-null   float64
#  7   Color         1000 non-null   object
#  8   Size          1000 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 70.4+ KB

# %%
data.describe().transpose()
# Out:
#              count        mean         std        min         25%         50%  \
# User ID     1000.0   50.419000   28.781310   1.000000   26.000000   50.000000
# Product ID  1000.0  500.500000  288.819436   1.000000  250.750000  500.500000
# Price       1000.0   55.785000   26.291748  10.000000   33.000000   57.000000
# Rating      1000.0    2.993135    1.153185   1.000967    1.992786    2.984003
#
#                    75%          max
# User ID      75.000000   100.000000
# Product ID  750.250000  1000.000000
# Price        78.250000   100.000000
# Rating        3.985084     4.987964

# %%
data[data['Rating'] < 4 ]
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 0         19           1        Dress  Adidas    Men's Fashion     40
# 2         25           3        Dress  Adidas  Women's Fashion     44
# 3         57           4        Shoes    Zara    Men's Fashion     23
# 5         98           6        Dress  Adidas    Men's Fashion     47
# 6         16           7        Jeans   Gucci    Men's Fashion     37
# ..       ...         ...          ...     ...              ...    ...
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 998        8         999      T-shirt    Zara  Women's Fashion     68
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 0    1.043159   Black   XL
# 2    3.337938  Yellow   XL
# 3    1.049523   White    S
# 5    1.379566  Yellow    L
# 6    1.356750   White   XL
# ..        ...     ...  ...
# 995  1.620081   Black    M
# 996  1.544464   Green    L
# 997  3.961913   White    L
# 998  3.089722    Blue    S
# 999  3.093553   White    L
#
# [752 rows x 9 columns]

# %%
data['Rating'].mean()
# Out:
# np.float64(2.9931351057620845)

# %%
data[data['Brand']== 'Adidas']
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 0         19           1        Dress  Adidas    Men's Fashion     40
# 2         25           3        Dress  Adidas  Women's Fashion     44
# 4         79           5      T-shirt  Adidas    Men's Fashion     79
# 5         98           6        Dress  Adidas    Men's Fashion     47
# 10        69          11      T-shirt  Adidas    Men's Fashion     51
# ..       ...         ...          ...     ...              ...    ...
# 957       46         958        Shoes  Adidas    Men's Fashion     16
# 961        4         962        Shoes  Adidas  Women's Fashion     97
# 988       67         989      T-shirt  Adidas    Men's Fashion     78
# 994       34         995      Sweater  Adidas    Kids' Fashion     58
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 0    1.043159   Black   XL
# 2    3.337938  Yellow   XL
# 4    4.302773   Black    M
# 5    1.379566  Yellow    L
# 10   1.160988     Red    S
# ..        ...     ...  ...
# 957  2.204638   Green    M
# 961  2.608359   Green    L
# 988  4.715257   Black    S
# 994  4.395112     Red    S
# 999  3.093553   White    L
#
# [198 rows x 9 columns]

# %%
data[data['Brand']== 'Nike']
# Out:
#      User ID  Product ID Product Name Brand         Category  Price    Rating  \
# 12         9          13        Jeans  Nike    Kids' Fashion     35  1.601194
# 29        20          30      Sweater  Nike    Kids' Fashion     99  3.110114
# 31        98          32      T-shirt  Nike    Kids' Fashion     78  3.447289
# 37        60          38      T-shirt  Nike    Kids' Fashion     76  2.663068
# 43        78          44        Jeans  Nike    Kids' Fashion     74  2.039157
# ..       ...         ...          ...   ...              ...    ...       ...
# 978       77         979      T-shirt  Nike    Men's Fashion     96  1.893289
# 980       35         981        Shoes  Nike  Women's Fashion     97  3.444968
# 981       50         982        Jeans  Nike    Kids' Fashion     11  4.038689
# 990       60         991        Shoes  Nike    Kids' Fashion     25  4.972677
# 996       42         997      Sweater  Nike    Kids' Fashion     13  1.544464
#
#       Color Size
# 12      Red    M
# 29    Green   XL
# 31    White   XL
# 37   Yellow    S
# 43    White    M
# ..      ...  ...
# 978    Blue    S
# 980   White   XL
# 981   Green    S
# 990     Red    L
# 996   Green    L
#
# [214 rows x 9 columns]

# %%
data['Brand'].describe()
# Out:
# count     1000
# unique       5
# top       Nike
# freq       214
# Name: Brand, dtype: object

# %%
data.head(3)
# Out:
#    User ID  Product ID Product Name   Brand         Category  Price    Rating  \
# 0       19           1        Dress  Adidas    Men's Fashion     40  1.043159
# 1       97           2        Shoes     H&M  Women's Fashion     82  4.026416
# 2       25           3        Dress  Adidas  Women's Fashion     44  3.337938
#
#     Color Size
# 0   Black   XL
# 1   Black    L
# 2  Yellow   XL

# %%
data[(data['Color'] == 'Black') & (data['Brand'] == 'Nike') & (data['Category'] == "Men's Fashion" )]
# Out:
#      User ID  Product ID Product Name Brand       Category  Price    Rating  \
# 281       18         282        Jeans  Nike  Men's Fashion     75  1.266590
# 287       13         288      Sweater  Nike  Men's Fashion     38  2.108828
# 292        9         293      Sweater  Nike  Men's Fashion     96  2.769661
# 310       55         311        Jeans  Nike  Men's Fashion     55  4.803390
# 324       67         325      T-shirt  Nike  Men's Fashion     91  2.668089
# 373       23         374        Jeans  Nike  Men's Fashion     20  1.474025
# 405       89         406        Shoes  Nike  Men's Fashion     54  1.751392
# 476      100         477      Sweater  Nike  Men's Fashion     30  1.559271
# 866        3         867        Jeans  Nike  Men's Fashion     90  4.235109
# 915       89         916      Sweater  Nike  Men's Fashion     91  3.456680
# 923       92         924      Sweater  Nike  Men's Fashion     80  3.703265
#
#      Color Size
# 281  Black    M
# 287  Black    M
# 292  Black   XL
# 310  Black    L
# 324  Black   XL
# 373  Black    S
# 405  Black    L
# 476  Black    S
# 866  Black    S
# 915  Black    M
# 923  Black    M

# %% [markdown]
# # Data Visualization

# %%
data.columns
# Out:
# Index(['User ID', 'Product ID', 'Product Name', 'Brand', 'Category', 'Price',
#        'Rating', 'Color', 'Size'],
#       dtype='object')

# %%
sns.lineplot(data['Price'])
plt.show()

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

diamonds = sns.load_dataset("diamonds")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(x="clarity", y="carat",
              color="b", order=clarity_ranking,
              scale="linear", data=diamonds)
# Out:
# C:\Users\guesm\AppData\Local\Temp\ipykernel_25224\2975645759.py:7: FutureWarning:
#
# The `scale` parameter has been renamed to `width_method` and will be removed in v0.15. Pass `width_method='linear' for the same effect.
#   sns.boxenplot(x="clarity", y="carat",
# <Axes: xlabel='clarity', ylabel='carat'>

# %%
sns.displot(data['Rating'])
plt.show()

# %%
data.columns
# Out:
# Index(['User ID', 'Product ID', 'Product Name', 'Brand', 'Category', 'Price',
#        'Rating', 'Color', 'Size'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Product Count by Category')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='Price', bins=10)
plt.xlabel('Price')
plt.ylabel('Count')
plt.title('Product Price Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Price', y='Rating')
plt.xlabel('Price')
plt.ylabel('Rating')
plt.title('Price vs Rating')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Category', y='Price')
plt.xlabel('Category')
plt.ylabel('Price')
plt.title('Product Price by Category')
plt.xticks(rotation=45)
plt.show()

# %%
# Set up the figure and axes
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Plot 1: Bar plot of categories
axs[0, 0].set_title('Category Distribution')
sns.countplot(x='Category', data=data, ax=axs[0, 0])
axs[0, 0].tick_params(axis='x', rotation=45)

# Plot 2: Histogram of prices
axs[0, 1].set_title('Price Distribution')
sns.histplot(data=data, x='Price', kde=True, ax=axs[0, 1])

# Plot 3: Box plot of ratings
axs[1, 0].set_title('Rating Distribution')
sns.boxplot(data=data, x='Rating', ax=axs[1, 0])

# Plot 4: Bar plot of colors
axs[1, 1].set_title('Color Distribution')
sns.countplot(x='Color', data=data, ax=axs[1, 1])
axs[1, 1].tick_params(axis='x', rotation=45)

# Adjust the layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
columns = ['Price', 'Rating']

# Compute the correlation matrix
corr_matrix = data[columns].corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')

# Customize the plot
plt.title('Correlation Heatmap')
plt.xticks(rotation=45)
plt.yticks(rotation=0)

# Display the plot
plt.show()
